# %% [markdown]
# Tache 3 — JSON basique : Charger et afficher les missions
#
# Notions : `json.load()`, accès aux clés, boucle sur une liste de dicts
#
# Objectif : Charger le fichier missions.json, afficher un résumé, calculer le budget total et identifier les missions extrêmes.

# %% [markdown]
# Etape 1 : Charger le fichier missions.json

# %%
import json

# Ouvrir et charger le fichier JSON
# json.load() transforme le contenu JSON en dictionnaire Python
with open("mission_data/missions.json", "r", encoding="utf-8") as f:
    donnees = json.load(f)

# Les missions sont dans la clé "missions" du dictionnaire
missions = donnees["missions"]
print(f"Nombre de missions chargées : {len(missions)}")
# Out:
# Nombre de missions chargées : 6

# %% [markdown]
# Etape 2 : Afficher le résumé de chaque mission

# %%
# Parcourir la liste des missions et afficher les infos
for mission in missions:
    mid = mission["id"]
    nom = mission["nom"]
    dest = mission["destination"]
    duree = mission["duree_jours"]
    nb_equipage = len(mission["equipage"])  # len() compte les éléments de la liste
    budget = mission["budget_millions_usd"]
    
    # f-string pour formater l'affichage
    # {:,} ajoute des séparateurs de milliers (ex: 18,500)
    print(f"[{mid}] {nom} → {dest} | {duree} jours | Équipage : {nb_equipage} | Budget : {budget:,} M$")
# Out:
# [MSN-001] Artemis IV → Lune | 21 jours | Équipage : 3 | Budget : 4,200 M$
# [MSN-002] Ares Genesis → Mars | 680 jours | Équipage : 4 | Budget : 18,500 M$
# [MSN-003] Europa Probe → Europe (Jupiter) | 2190 jours | Équipage : 0 | Budget : 5,600 M$
# [MSN-004] Titan Explorer → Titan (Saturne) | 2920 jours | Équipage : 0 | Budget : 7,800 M$
# [MSN-005] Helios Station → Orbite solaire | 365 jours | Équipage : 2 | Budget : 3,100 M$
# [MSN-007] Stellar Link → Jupiter | 1200 jours | Équipage : 0 | Budget : 9,500 M$

# %% [markdown]
# Etape 3 : Calculer le budget total

# %%
# Additionner tous les budgets
budget_total = 0
for mission in missions:
    budget_total += mission["budget_millions_usd"]

print(f"\n Budget total de toutes les missions : {budget_total:,} M$")
# Out:
#  Budget total de toutes les missions : 48,700 M$

# %% [markdown]
# Etape 4 : Mission la plus longue et la plus courte

# %%
# Trouver la mission la plus longue
# On initialise avec la première mission
plus_longue = missions[0]
plus_courte = missions[0]

for mission in missions:
    if mission["duree_jours"] > plus_longue["duree_jours"]:
        plus_longue = mission
    if mission["duree_jours"] < plus_courte["duree_jours"]:
        plus_courte = mission

print(f" Mission la plus longue : {plus_longue['nom']} ({plus_longue['duree_jours']} jours)")
print(f" Mission la plus courte : {plus_courte['nom']} ({plus_courte['duree_jours']} jours)")
# Out:
#  Mission la plus longue : Titan Explorer (2920 jours)
#  Mission la plus courte : Artemis IV (21 jours)
